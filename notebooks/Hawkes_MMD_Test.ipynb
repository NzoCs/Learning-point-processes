# %% [markdown]
# # Test MMD : comparaison de deux processus de Poisson
#
# Comparaison de deux processus de Poisson homogènes via le test MMD two-sample.
#
# - **Poisson 1** : intensité μ₁
# - **Poisson 2** : intensité μ₂ (différente)
#
# **Objectif** : vérifier que le test MMD détecte la différence entre les deux distributions.

# %% [markdown]
# ## 1. Imports & Helpers

# %%
import os
os.environ["TORCHDYNAMO_DISABLE"] = "1"  # désactive torch.compile / Inductor (pas de cl.exe nécessaire)

import numpy as np
import torch
import matplotlib.pyplot as plt
from typing import List, Dict

from new_ltpp.data.generation.hawkes import HawkesSimulator
from new_ltpp.data.generation.simulation_manager import SimulationManager
from new_ltpp.shared_types import Batch

from new_ltpp.evaluation.statistical_testing import MMDTwoSampleTest
from new_ltpp.evaluation.statistical_testing.kernels import SIGKernel

print("Modules importés.")
# Out:
# Modules importés.

# %%
def simulate_poisson(mu: float, dim_process: int = 1, num_simulations: int = 200,
                     end_time: float = 10.0, seed=None) -> List[Dict]:
    """Simule un processus de Poisson (Hawkes avec alpha=0)."""
    sim = HawkesSimulator(
        mu=[mu] * dim_process,
        alpha=[[0.0] * dim_process] * dim_process,
        beta=[[1.0] * dim_process] * dim_process,
        dim_process=dim_process,
        start_time=0, end_time=end_time, seed=seed,
    )
    manager = SimulationManager(
        simulation_func=sim.simulate,
        dim_process=dim_process,
        start_time=0, end_time=end_time,
    )
    return manager.bulk_simulate(num_simulations)


def sequences_to_batch(sequences: List[Dict], max_len: int | None = None) -> Batch:
    """Convertit une liste de séquences en Batch paddé."""
    if max_len is None:
        max_len = max(s["seq_len"] for s in sequences)

    time_seqs, delta_seqs, type_seqs, masks = [], [], [], []
    for s in sequences:
        L = s["seq_len"]
        time_seqs.append(s["time_since_start"]  + [0.0] * (max_len - L))
        delta_seqs.append(s["time_since_last_event"] + [0.0] * (max_len - L))
        type_seqs.append(s["type_event"] + [0] * (max_len - L))
        masks.append([True] * L + [False] * (max_len - L))

    return Batch(
        time_seqs=torch.tensor(time_seqs, dtype=torch.float32),
        time_delta_seqs=torch.tensor(delta_seqs, dtype=torch.float32),
        type_seqs=torch.tensor(type_seqs, dtype=torch.long),
        valid_event_mask=torch.tensor(masks, dtype=torch.bool),
    )


print("Helpers prêts.")
# Out:
# Helpers prêts.

# %% [markdown]
# ## 2. Définition des deux processus de Poisson

# %%
DIM = 1          # Processus univarié
NUM_SIM = 200    # Séquences par processus
END_TIME = 10.0  # Horizon de simulation

MU_1 = 5.0   # Intensité du processus 1
MU_2 = 15.0  # Intensité du processus 2 (plus élevée → distributions différentes)

print(f"Processus 1 : Poisson(μ={MU_1})  →  ~{MU_1 * END_TIME:.0f} événements/séq")
print(f"Processus 2 : Poisson(μ={MU_2})  →  ~{MU_2 * END_TIME:.0f} événements/séq")
# Out:
# Processus 1 : Poisson(μ=5.0)  →  ~50 événements/séq
# Processus 2 : Poisson(μ=15.0)  →  ~150 événements/séq

# %% [markdown]
# ## 3. Génération des données
#
# On simule deux grands pools de séquences pour pouvoir effectuer
# du sous-échantillonnage répété lors des tests empiriques.

# %%
N_POOL        = 300   # séquences dans chaque pool de tirage
N_REPEATS     = 5     # répétitions indépendantes par point de sweep
N_PERMUTATIONS = 99   # permutations par test MMD
ALPHA         = 0.05  # niveau du test

print(f"Simulation pool Poisson(μ₁={MU_1})...")
seqs_A = simulate_poisson(MU_1, dim_process=DIM, num_simulations=N_POOL,
                           end_time=END_TIME, seed=42)
print(f"  → {len(seqs_A)} séquences, longueur moy = {np.mean([s['seq_len'] for s in seqs_A]):.1f}")

print(f"\nSimulation pool Poisson(μ₂={MU_2})...")
seqs_B = simulate_poisson(MU_2, dim_process=DIM, num_simulations=N_POOL,
                           end_time=END_TIME, seed=123)
print(f"  → {len(seqs_B)} séquences, longueur moy = {np.mean([s['seq_len'] for s in seqs_B]):.1f}")

global_max_len = max(s["seq_len"] for s in seqs_A + seqs_B)
print(f"\nLongueur max (padding global) : {global_max_len}")
# Out:
# Simulation pool Poisson(μ₁=5.0)...
# Simulating 300 processes: 100%|██████████| 300/300 [00:01<00:00, 179.67it/s]
#   → 300 séquences, longueur moy = 51.2
#
# Simulation pool Poisson(μ₂=15.0)...
# Simulating 300 processes: 100%|██████████| 300/300 [00:03<00:00, 80.70it/s]
#   → 300 séquences, longueur moy = 150.4
#
# Longueur max (padding global) : 187

# %% [markdown]
# ## 4. Fonctions d'analyse empirique
#
# Pour chaque point de sweep on exécute `N_REPEATS` tests indépendants :
# - **H0** : deux sous-échantillons tirés du même pool (même distribution)
# - **H1** : un sous-échantillon de chaque processus (distributions différentes)
#
# On récupère la distribution nulle (permutations), la statistique observée, et on estime :
# - **Erreur de Type 1** : proportion de tests H0 où H0 est rejetée (faux positif)
# - **Erreur de Type 2** : proportion de tests H1 où H0 n'est pas rejetée (faux négatif)

# %%
def subsample_batch(seqs_pool: List[Dict], n: int, max_len: int) -> Batch:
    idx = np.random.choice(len(seqs_pool), n, replace=True)
    return sequences_to_batch([seqs_pool[i] for i in idx], max_len)


def run_one_test(test: MMDTwoSampleTest, batch_x: Batch, batch_y: Batch):
    """Retourne (mmd_observé, distribution_nulle_perms, p_value)."""
    observed, perm_mmds = test._permutation_test_from_batches(batch_x, batch_y)
    p_val = (sum(1 for pm in perm_mmds if pm >= observed) + 1) / (len(perm_mmds) + 1)
    return observed, perm_mmds, p_val


def empirical_analysis(
    kernel,
    seqs_X: List[Dict],
    seqs_Y: List[Dict],
    max_len: int,
    n_repeats: int = N_REPEATS,
    batch_size: int = 32,
    n_permutations: int = N_PERMUTATIONS,
    alpha: float = ALPHA,
) -> Dict:
    """
    Estime empiriquement les erreurs de Type 1 et Type 2.
    H0 : deux sous-échantillons indépendants de seqs_X (même distribution).
    H1 : un sous-échantillon de seqs_X vs un de seqs_Y (distributions différentes).
    """
    test = MMDTwoSampleTest(kernel=kernel, n_permutations=n_permutations)
    h0_mmds, h0_pvals, h0_perm_dists = [], [], []
    h1_mmds, h1_pvals, h1_perm_dists = [], [], []

    for _ in range(n_repeats):
        # H0 — même distribution
        bx = subsample_batch(seqs_X, batch_size, max_len)
        by = subsample_batch(seqs_X, batch_size, max_len)
        obs, perms, pval = run_one_test(test, bx, by)
        h0_mmds.append(obs); h0_perm_dists.extend(perms); h0_pvals.append(pval)

        # H1 — distributions différentes
        ba = subsample_batch(seqs_X, batch_size, max_len)
        bb = subsample_batch(seqs_Y, batch_size, max_len)
        obs, perms, pval = run_one_test(test, ba, bb)
        h1_mmds.append(obs)
        h1_perm_dists.extend(perms) 
        h1_pvals.append(pval)

    return {
        "h0_mmds": h0_mmds, "h0_pvals": h0_pvals, "h0_perm_dists": h0_perm_dists,
        "h1_mmds": h1_mmds, "h1_pvals": h1_pvals, "h1_perm_dists": h1_perm_dists,
        "type1_error": float(np.mean([p < alpha for p in h0_pvals])),
        "type2_error": float(np.mean([p >= alpha for p in h1_pvals])),
    }


def plot_sweep(sweep_values, results_list, param_name: str, param_label: str, alpha: float = ALPHA):
    """
    Fig 1 — pour chaque valeur : distribution nulle (permutations H0),
             MMD observées sous H0 (bleu) et sous H1 (rouge), seuil critique.
    Fig 2 — courbes d'erreurs de Type 1 et Type 2.
    """
    n = len(sweep_values)

    # ── Figure 1 : distributions MMD² ─────────────────────────────────────
    fig1, axes = plt.subplots(1, n, figsize=(4 * n, 4.5), sharey=False)
    if n == 1:
        axes = [axes]

    for i, (val, res) in enumerate(zip(sweep_values, results_list)):
        ax = axes[i]

        # Distribution nulle (permutations sous H0)
        ax.hist(res["h0_perm_dists"], bins=40, color="gray", alpha=0.5,
                density=True, label="Null (perms H0)")

        # Seuil critique (quantile 1-α de la distribution nulle)
        thresh = float(np.percentile(res["h0_perm_dists"], 100 * (1 - alpha)))
        ax.axvline(thresh, color="black", linestyle="--", linewidth=1.5,
                   label=f"Seuil α={alpha}")

        # MMD observées sous H0 (traits fins bleus + trait épais pour la moyenne)
        for mmd in res["h0_mmds"]:
            ax.axvline(mmd, color="steelblue", alpha=0.35, linewidth=1)
        h0_mean = float(np.mean(res["h0_mmds"]))
        ax.axvline(h0_mean, color="steelblue", linewidth=2.5,
                   label=f"H0 moy={h0_mean:.4f}")

        # MMD observées sous H1 (traits fins rouges + trait épais pour la moyenne)
        for mmd in res["h1_mmds"]:
            ax.axvline(mmd, color="crimson", alpha=0.35, linewidth=1)
        h1_mean = float(np.mean(res["h1_mmds"]))
        ax.axvline(h1_mean, color="crimson", linewidth=2.5,
                   label=f"H1 moy={h1_mean:.4f}")

        ax.set_title(f"{param_label}={val}", fontsize=11)
        ax.set_xlabel("MMD²", fontsize=10)
        if i == 0:
            ax.set_ylabel("Densité", fontsize=10)
        ax.legend(fontsize=7, loc="upper right")
        ax.grid(True, alpha=0.3)

    fig1.suptitle(f"Distributions MMD² — sweep {param_name}",
                  fontsize=13, fontweight="bold")
    plt.tight_layout()
    plt.show()

    # ── Figure 2 : courbes d'erreurs ──────────────────────────────────────
    type1_errors = [r["type1_error"] for r in results_list]
    type2_errors = [r["type2_error"] for r in results_list]
    xvals = list(range(n))
    xlabels = [str(v) for v in sweep_values]

    fig2, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

    ax1.plot(xvals, type1_errors, "o-", color="steelblue", linewidth=2, markersize=8)
    ax1.axhline(y=alpha, color="red", linestyle="--", alpha=0.8,
                label=f"Niveau nominal α={alpha}")
    ax1.set_xticks(xvals); ax1.set_xticklabels(xlabels, rotation=20)
    ax1.set_xlabel(param_label, fontsize=11)
    ax1.set_ylabel("Erreur Type 1 (faux positifs)", fontsize=11)
    ax1.set_title(f"Erreur de Type 1 vs {param_name}", fontsize=12)
    ax1.set_ylim(-0.05, 1.05); ax1.legend(); ax1.grid(True, alpha=0.3)

    ax2.plot(xvals, type2_errors, "s-", color="crimson", linewidth=2, markersize=8)
    ax2.set_xticks(xvals); ax2.set_xticklabels(xlabels, rotation=20)
    ax2.set_xlabel(param_label, fontsize=11)
    ax2.set_ylabel("Erreur Type 2 (faux négatifs)", fontsize=11)
    ax2.set_title(f"Erreur de Type 2 vs {param_name}", fontsize=12)
    ax2.set_ylim(-0.05, 1.05); ax2.grid(True, alpha=0.3)

    fig2.suptitle(f"Erreurs empiriques — sweep {param_name}",
                  fontsize=13, fontweight="bold")
    plt.tight_layout()
    plt.show()


print("Fonctions d'analyse prêtes.")
# Out:
# Fonctions d'analyse prêtes.

# %% [markdown]
# ## 5. Sweep : scaling RBF du SigKernel
#
# On fixe les deux processus (μ₁=5, μ₂=15) et on fait varier le paramètre `rbf_scaling`
# qui multiplie le bandwidth de la médiane heuristique du kernel statique RBF.
#
# **Attendu** : un scaling trop petit ou trop grand devrait dégrader la puissance du test.

# %%
RBF_SCALINGS = [0.1, 0.3, 1.0, 3.0, 10.0]

print("=== Sweep rbf_scaling (SigKernel — kernel statique RBF) ===")
print(f"μ₁={MU_1}, μ₂={MU_2} | batch_size=32 | {N_REPEATS} répétitions | {N_PERMUTATIONS} permutations")
print("(peut prendre plusieurs minutes...)\n")

rbf_results = []
for s in RBF_SCALINGS:
    print(f"rbf_scaling={s} ...", end=" ", flush=True)
    kernel = SIGKernel(
        static_kernel_type="rbf",
        embedding_type="linear_interpolant",
        dyadic_order=3,
        num_event_types=DIM,
        rbf_scaling=s,
    )
    res = empirical_analysis(kernel, seqs_A, seqs_B, global_max_len)
    rbf_results.append(res)
    print(f"Type1={res['type1_error']:.2f}  Type2={res['type2_error']:.2f}")

print("\nDone.")
# Out:
# === Sweep rbf_scaling (SigKernel — kernel statique RBF) ===
# μ₁=5.0, μ₂=15.0 | batch_size=32 | 5 répétitions | 99 permutations
# (peut prendre plusieurs minutes...)
#
# rbf_scaling=0.1 ...

# %%
plot_sweep(RBF_SCALINGS, rbf_results, "rbf_scaling", "rbf_scaling")

# %% [markdown]
# ## 6. Sweep : divergence des processus (μ₂)
#
# On fixe μ₁=5 et `rbf_scaling=1.0`, et on fait varier μ₂.
# Quand μ₂ → μ₁ les deux processus deviennent identiques (H0 vraie),
# quand μ₂ s'éloigne la différence devient de plus en plus facile à détecter.

# %%
KERNEL_FIXED = SIGKernel(
    static_kernel_type="rbf",
    embedding_type="linear_interpolant",
    dyadic_order=3,
    num_event_types=DIM,
    rbf_scaling=1.0,
)

MU_2_VALUES = [5.0, 7.0, 10.0, 15.0, 20.0, 30.0]

print("=== Sweep μ₂ (divergence des processus de Poisson) ===")
print(f"μ₁={MU_1} fixe | rbf_scaling=1.0 | batch_size=32 | {N_REPEATS} répétitions\n")

mu_results = []
for mu2 in MU_2_VALUES:
    print(f"μ₂={mu2} ...", end=" ", flush=True)
    seqs_B2 = simulate_poisson(mu2, dim_process=DIM, num_simulations=N_POOL,
                                end_time=END_TIME)
    max_len2 = max(s["seq_len"] for s in seqs_A + seqs_B2)
    res = empirical_analysis(KERNEL_FIXED, seqs_A, seqs_B2, max_len2)
    mu_results.append(res)
    print(f"Type1={res['type1_error']:.2f}  Type2={res['type2_error']:.2f}")

print("\nDone.")

# %%
plot_sweep(MU_2_VALUES, mu_results, "μ₂", "μ₂")

# %% [markdown]
# ## 7. Sweep : taille de batch
#
# On fixe μ₁=5, μ₂=15, `rbf_scaling=1.0` et on fait varier la taille des mini-batches.
# Un batch plus grand donne une meilleure estimation de la MMD mais coûte plus cher.

# %%
BATCH_SIZES = [8, 16, 32, 64]

print("=== Sweep taille de batch ===")
print(f"μ₁={MU_1}, μ₂={MU_2} | rbf_scaling=1.0 | {N_REPEATS} répétitions\n")

bs_results = []
for bs in BATCH_SIZES:
    print(f"batch_size={bs} ...", end=" ", flush=True)
    res = empirical_analysis(KERNEL_FIXED, seqs_A, seqs_B, global_max_len,
                             batch_size=bs)
    bs_results.append(res)
    print(f"Type1={res['type1_error']:.2f}  Type2={res['type2_error']:.2f}")

print("\nDone.")

# %% [markdown]
# plot_sweep(BATCH_SIZES, bs_results, "batch_size", "Taille de batch")
