# %%
import torch

A = torch.randn((5, 3))

# %%
min = A.min(dim=1)

min
# Out:
# torch.return_types.min(
# values=tensor([-0.4134, -0.5762, -1.1937, -0.5573, -0.6296]),
# indices=tensor([2, 2, 0, 2, 2]))
